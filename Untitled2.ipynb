# %% [markdown]
# <a href="https://colab.research.google.com/github/sumithkumar2001/Neural-HW-5/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NOTE: If you encounter `ModuleNotFoundError: No module named 'torch'`, install the required packages using:
# pip install torch torchvision matplotlib

try:
    import torch
    import torch.nn as nn
    import torch.optim as optim
    import torchvision
    from torchvision import datasets, transforms
    from torch.utils.data import DataLoader
    import matplotlib.pyplot as plt
    import numpy as np
    import os
except ModuleNotFoundError as e:
    raise ModuleNotFoundError("Missing a required module. Please install with: pip install torch torchvision matplotlib") from e

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Hyperparameters
latent_dim = 100
batch_size = 128
lr = 0.0002
num_epochs = 100
sample_dir = 'samples'
os.makedirs(sample_dir, exist_ok=True)

# MNIST dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

dataset = datasets.MNIST(root='data/', train=True, transform=transform, download=True)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Generator
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(latent_dim, 256),
            nn.ReLU(True),
            nn.Linear(256, 512),
            nn.ReLU(True),
            nn.Linear(512, 1024),
            nn.ReLU(True),
            nn.Linear(1024, 28*28),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        img = img.view(z.size(0), 1, 28, 28)
        return img

# Discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )

    def forward(self, img):
        img_flat = img.view(img.size(0), -1)
        validity = self.model(img_flat)
        return validity

# Initialize models and optimizers
generator = Generator().to(device)
discriminator = Discriminator().to(device)

criterion = nn.BCELoss()
optimizer_G = optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
optimizer_D = optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))

fixed_noise = torch.randn(64, latent_dim, device=device)

def save_samples(epoch):
    generator.eval()
    with torch.no_grad():
        fake_images = generator(fixed_noise).detach().cpu()
    generator.train()

    grid = np.transpose(torchvision.utils.make_grid(fake_images, padding=2, normalize=True), (1, 2, 0))
    plt.figure(figsize=(8, 8))
    plt.imshow(grid)
    plt.axis('off')
    plt.title(f'Epoch {epoch}')
    plt.savefig(f'{sample_dir}/epoch_{epoch}.png')
    plt.close()

# Training loop
losses_G = []
losses_D = []

for epoch in range(num_epochs + 1):
    for i, (imgs, _) in enumerate(dataloader):

        real_imgs = imgs.to(device)
        real_labels = torch.ones(imgs.size(0), 1, device=device)
        fake_labels = torch.zeros(imgs.size(0), 1, device=device)

        # Train Generator
        optimizer_G.zero_grad()
        z = torch.randn(imgs.size(0), latent_dim, device=device)
        generated_imgs = generator(z)
        g_loss = criterion(discriminator(generated_imgs), real_labels)
        g_loss.backward()
        optimizer_G.step()

        # Train Discriminator
        optimizer_D.zero_grad()
        real_loss = criterion(discriminator(real_imgs), real_labels)
        fake_loss = criterion(discriminator(generated_imgs.detach()), fake_labels)
        d_loss = real_loss + fake_loss
        d_loss.backward()
        optimizer_D.step()

    losses_G.append(g_loss.item())
    losses_D.append(d_loss.item())

    print(f"Epoch [{epoch}/{num_epochs}] | D Loss: {d_loss.item():.4f} | G Loss: {g_loss.item():.4f}")

    if epoch in [0, 50, 100]:
        save_samples(epoch)

# Plot losses
plt.figure(figsize=(10, 5))
plt.plot(losses_G, label='Generator Loss')
plt.plot(losses_D, label='Discriminator Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Generator and Discriminator Loss During Training')
plt.savefig('loss_plot.png')
plt.show()
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 129MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 42.1MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 82.8MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 6.59MB/s]
# Epoch [0/100] | D Loss: 1.0608 | G Loss: 0.5335
# Epoch [1/100] | D Loss: 0.3376 | G Loss: 1.6694
# Epoch [2/100] | D Loss: 0.7323 | G Loss: 0.9492
# Epoch [3/100] | D Loss: 0.6126 | G Loss: 1.4715
# Epoch [4/100] | D Loss: 1.4471 | G Loss: 5.9579
# Epoch [5/100] | D Loss: 0.3206 | G Loss: 2.0644
# Epoch [6/100] | D Loss: 0.3400 | G Loss: 2.3081
# Epoch [7/100] | D Loss: 1.0744 | G Loss: 0.4450
# Epoch [8/100] | D Loss: 0.3829 | G Loss: 2.4794
# Epoch [9/100] | D Loss: 0.2864 | G Loss: 7.9310
# Epoch [10/100] | D Loss: 0.6944 | G Loss: 1.5372
# Epoch [11/100] | D Loss: 0.2308 | G Loss: 2.8182
# Epoch [12/100] | D Loss: 1.1707 | G Loss: 3.7380
# Epoch [13/100] | D Loss: 0.1496 | G Loss: 2.4237
# Epoch [14/100] | D Loss: 0.4087 | G Loss: 2.8676
# Epoch [15/100] | D Loss: 0.3008 | G Loss: 2.0004
# Epoch [16/100] | D Loss: 0.4867 | G Loss: 2.4117
# Epoch [17/100] | D Loss: 2.3825 | G Loss: 0.1080
# Epoch [18/100] | D Loss: 2.2052 | G Loss: 9.3825
# Epoch [19/100] | D Loss: 0.3794 | G Loss: 2.9124
# Epoch [20/100] | D Loss: 0.2053 | G Loss: 2.4955
# Epoch [21/100] | D Loss: 0.1275 | G Loss: 2.9305
# Epoch [22/100] | D Loss: 0.1804 | G Loss: 3.2403
# Epoch [23/100] | D Loss: 0.3977 | G Loss: 1.7368
# Epoch [24/100] | D Loss: 0.4048 | G Loss: 1.6620
# Epoch [25/100] | D Loss: 0.2580 | G Loss: 2.7806
# Epoch [26/100] | D Loss: 0.0828 | G Loss: 3.3192
# Epoch [27/100] | D Loss: 0.5481 | G Loss: 1.8220
# Epoch [28/100] | D Loss: 0.0911 | G Loss: 2.9625
# Epoch [29/100] | D Loss: 0.0228 | G Loss: 4.2179
# Epoch [30/100] | D Loss: 0.5136 | G Loss: 2.7836
# Epoch [31/100] | D Loss: 1.5881 | G Loss: 14.2477
# Epoch [32/100] | D Loss: 0.0955 | G Loss: 3.1818
# Epoch [33/100] | D Loss: 0.2708 | G Loss: 2.4541
# Epoch [34/100] | D Loss: 0.0738 | G Loss: 4.1266
# Epoch [35/100] | D Loss: 0.1461 | G Loss: 3.3446
# Epoch [36/100] | D Loss: 0.0660 | G Loss: 3.9347
# Epoch [37/100] | D Loss: 0.0232 | G Loss: 4.7405
# Epoch [38/100] | D Loss: 0.0095 | G Loss: 5.7822
# Epoch [39/100] | D Loss: 0.0086 | G Loss: 6.7872
# Epoch [40/100] | D Loss: 0.0064 | G Loss: 6.7055
# Epoch [41/100] | D Loss: 0.0008 | G Loss: 7.7400
# Epoch [42/100] | D Loss: 0.0006 | G Loss: 7.7242
# Epoch [43/100] | D Loss: 0.0007 | G Loss: 7.2480
# Epoch [44/100] | D Loss: 0.0014 | G Loss: 6.6772
# Epoch [45/100] | D Loss: 0.0000 | G Loss: 10.0100
# Epoch [46/100] | D Loss: 0.0000 | G Loss: 10.1816
# Epoch [47/100] | D Loss: 0.0000 | G Loss: 10.8080
# Epoch [48/100] | D Loss: 0.0001 | G Loss: 9.2722
# Epoch [49/100] | D Loss: 0.0015 | G Loss: 7.9768
# Epoch [50/100] | D Loss: 0.0004 | G Loss: 8.3453
# Epoch [51/100] | D Loss: 0.0008 | G Loss: 9.1782
# Epoch [52/100] | D Loss: 0.0001 | G Loss: 8.9707
# Epoch [53/100] | D Loss: 0.0000 | G Loss: 10.2573
# Epoch [54/100] | D Loss: 0.0002 | G Loss: 8.7840
# Epoch [55/100] | D Loss: 0.0001 | G Loss: 9.8240
# Epoch [56/100] | D Loss: 0.0000 | G Loss: 51.6016
# Epoch [57/100] | D Loss: 0.0000 | G Loss: 51.2122
# Epoch [58/100] | D Loss: 0.0000 | G Loss: 50.9643
# Epoch [59/100] | D Loss: 0.0000 | G Loss: 50.9125
# Epoch [60/100] | D Loss: 0.0000 | G Loss: 50.8133
# Epoch [61/100] | D Loss: 0.0000 | G Loss: 50.7574
# Epoch [62/100] | D Loss: 0.0000 | G Loss: 50.8006
# Epoch [63/100] | D Loss: 0.0000 | G Loss: 50.6848
# Epoch [64/100] | D Loss: 0.0000 | G Loss: 50.6503
# Epoch [65/100] | D Loss: 0.0000 | G Loss: 50.6002
# Epoch [66/100] | D Loss: 0.0000 | G Loss: 50.5729
# Epoch [67/100] | D Loss: 0.0000 | G Loss: 50.5073
# Epoch [68/100] | D Loss: 0.0000 | G Loss: 50.4522
# Epoch [69/100] | D Loss: 0.0000 | G Loss: 50.4272
# Epoch [70/100] | D Loss: 0.0000 | G Loss: 50.3858
# Epoch [71/100] | D Loss: 0.0000 | G Loss: 50.3080
# Epoch [72/100] | D Loss: 0.0000 | G Loss: 50.3193
# Epoch [73/100] | D Loss: 0.0000 | G Loss: 50.3486
# Epoch [74/100] | D Loss: 0.0000 | G Loss: 50.2494
# Epoch [75/100] | D Loss: 0.0000 | G Loss: 50.2069
# Epoch [76/100] | D Loss: 0.0000 | G Loss: 50.1763
# Epoch [77/100] | D Loss: 0.0000 | G Loss: 50.1611
# Epoch [78/100] | D Loss: 0.0000 | G Loss: 50.2650
# Epoch [79/100] | D Loss: 0.0000 | G Loss: 50.0857
# Epoch [80/100] | D Loss: 0.0000 | G Loss: 50.0405
# Epoch [81/100] | D Loss: 0.0000 | G Loss: 50.0576
# Epoch [82/100] | D Loss: 0.0000 | G Loss: 49.9832
# Epoch [83/100] | D Loss: 0.0000 | G Loss: 49.9524
# Epoch [84/100] | D Loss: 0.0000 | G Loss: 49.9322
# Epoch [85/100] | D Loss: 0.0000 | G Loss: 49.8795
# Epoch [86/100] | D Loss: 0.0000 | G Loss: 49.8458
# Epoch [87/100] | D Loss: 0.0000 | G Loss: 49.7890
# Epoch [88/100] | D Loss: 0.0000 | G Loss: 49.7753
# Epoch [89/100] | D Loss: 0.0000 | G Loss: 49.6784
# Epoch [90/100] | D Loss: 0.0000 | G Loss: 49.6487
# Epoch [91/100] | D Loss: 0.0000 | G Loss: 49.5576
# Epoch [92/100] | D Loss: 0.0000 | G Loss: 49.4285
# Epoch [93/100] | D Loss: 0.0000 | G Loss: 49.2747
# Epoch [94/100] | D Loss: 0.0000 | G Loss: 49.1764
# Epoch [95/100] | D Loss: 0.0000 | G Loss: 48.9963
# Epoch [96/100] | D Loss: 0.0000 | G Loss: 48.7730
# Epoch [97/100] | D Loss: 0.0000 | G Loss: 48.6041
# Epoch [98/100] | D Loss: 0.0000 | G Loss: 48.5338
# Epoch [99/100] | D Loss: 0.0000 | G Loss: 48.3211
# Epoch [100/100] | D Loss: 0.0000 | G Loss: 48.2655
